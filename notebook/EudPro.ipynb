# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-498b64a2-08f6-4f83-8d07-3a13a26108c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-498b64a2-08f6-4f83-8d07-3a13a26108c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "EduPro Online Platform.xlsx"

users_df = pd.read_excel(file_path, sheet_name="Users")
courses_df = pd.read_excel(file_path, sheet_name="Courses")
teachers_df = pd.read_excel(file_path, sheet_name="Teachers")
transactions_df = pd.read_excel(file_path, sheet_name="Transactions")

# %%
print("Users Shape:", users_df.shape)
print("Courses Shape:", courses_df.shape)
print("Teachers Shape:", teachers_df.shape)
print("Transactions Shape:", transactions_df.shape)
# Out:
# Users Shape: (3000, 5)
# Courses Shape: (60, 8)
# Teachers Shape: (60, 7)
# Transactions Shape: (10000, 7)

# %%
print("========== USERS ==========")
display(users_df.head())

print("========== COURSES ==========")
display(courses_df.head())

print("========== TEACHERS ==========")
display(teachers_df.head())

print("========== TRANSACTIONS ==========")
display(transactions_df.head())
# Out:
# ========== USERS ==========
#    UserID        UserName  Age  Gender                             Email
# 0  U00001    wilsonjordan   15    Male            patricia27@hotmail.com
# 1  U00002        angela22   29  Female             hallrandy@hotmail.com
# 2  U00003  morrisonamanda   33  Female               ganderson@yahoo.com
# 3  U00004       fthornton   23  Female  christensencatherine@outlook.com
# 4  U00005  fostergeoffrey   21    Male            karenfuentes@yahoo.com
# ========== COURSES ==========
#   CourseID              CourseName CourseCategory CourseType   CourseLevel  \
# 0  CR00001           Python Basics    Programming       Paid      Beginner
# 1  CR00002        Java Programming    Programming       Free  Intermediate
# 2  CR00003       C++ for Beginners    Programming       Free      Beginner
# 3  CR00004         Advanced Python    Programming       Free      Beginner
# 4  CR00005  Full Stack Development    Programming       Free      Beginner
#
# ...

# %%
print("========== USERS INFO ==========")
users_df.info()

print("\n========== COURSES INFO ==========")
courses_df.info()

print("\n========== TEACHERS INFO ==========")
teachers_df.info()

print("\n========== TRANSACTIONS INFO ==========")
transactions_df.info()
# Out:
# ========== USERS INFO ==========
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   UserID    3000 non-null   object
#  1   UserName  3000 non-null   object
#  2   Age       3000 non-null   int64
#  3   Gender    3000 non-null   object
#  4   Email     3000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 117.3+ KB
#
# ========== COURSES INFO ==========
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CourseID        60 non-null     object
#  1   CourseName      60 non-null     object
#  2   CourseCategory  60 non-null     object
#  3   CourseType      60 non-null     object
#  4   CourseLevel     60 non-null     object
#  5   CoursePrice     60 non-null     float64
# ...

# %%
print("Users Duplicate :", users_df.duplicated().sum())
print("Courses Duplicate :", courses_df.duplicated().sum())
print("Teachers Duplicate :", teachers_df.duplicated().sum())
print("Transactions Duplicate :", transactions_df.duplicated().sum())
# Out:
# Users Duplicate : 0
# Courses Duplicate : 0
# Teachers Duplicate : 0
# Transactions Duplicate : 0

# %%
print(users_df.isnull().sum())
print()

print(courses_df.isnull().sum())
print()

print(teachers_df.isnull().sum())
print()

print(transactions_df.isnull().sum())
# Out:
# UserID      0
# UserName    0
# Age         0
# Gender      0
# Email       0
# dtype: int64
#
# CourseID          0
# CourseName        0
# CourseCategory    0
# CourseType        0
# CourseLevel       0
# CoursePrice       0
# CourseDuration    0
# CourseRating      0
# dtype: int64
#
# TeacherID            0
# TeacherName          0
# Age                  0
# Gender               0
# Expertise            0
# YearsOfExperience    0
# TeacherRating        0
# dtype: int64
#
# TransactionID      0
# UserID             0
# CourseID           0
# TransactionDate    0
# Amount             0
# PaymentMethod      0
# TeacherID          0
# dtype: int64

# %%
print("Course Categories:")
print(courses_df["CourseCategory"].unique())
print()

print("Course Types:")
print(courses_df["CourseType"].unique())
print()

print("Course Levels:")
print(courses_df["CourseLevel"].unique())
print()
`
print("Payment Methods:")
print(transactions_df["PaymentMethod"].unique())
print()

print("Teacher Expertise:")
print(teachers_df["Expertise"].unique())
# Out:
# Course Categories:
# ['Programming' 'Design' 'Business' 'Marketing' 'Data Science'
#  'Machine Learning' 'Cybersecurity' 'Project Management' 'Finance'
#  'Artificial Intelligence' 'Web Development' 'Digital Marketing']
#
# Course Types:
# ['Paid' 'Free']
#
# Course Levels:
# ['Beginner' 'Intermediate' 'Advanced']
#
# Payment Methods:
# ['PayPal' 'Bank Transfer' 'Credit Card']
#
# Teacher Expertise:
# ['Cybersecurity' 'Digital Marketing' 'Design' 'Machine Learning' 'Finance'
#  'Data Science' 'Project Management' 'Artificial Intelligence'
#  'Web Development' 'Business' 'Marketing' 'Programming']

# %%
merged_df = transactions_df.merge(users_df, on="UserID", how="left")
merged_df = merged_df.merge(courses_df, on="CourseID", how="left")
merged_df = merged_df.merge(teachers_df, on="TeacherID", how="left")

# %%
print("Merged Dataset Shape :", merged_df.shape)

merged_df.head()
# Out:
# Merged Dataset Shape : (10000, 24)
#   TransactionID  UserID CourseID TransactionDate  Amount  PaymentMethod  \
# 0       TT00001  U00003  CR00016      2025-10-25     0.0         PayPal
# 1       TT00002  U00003  CR00037      2025-01-13     0.0         PayPal
# 2       TT00003  U00003  CR00019      2025-03-28     0.0  Bank Transfer
# 3       TT00004  U00004  CR00048      2025-06-02     0.0  Bank Transfer
# 4       TT00005  U00004  CR00060      2025-08-10     0.0         PayPal
#
#   TeacherID        UserName  Age_x Gender_x  ...   CourseLevel CoursePrice  \
# 0   TC00040  morrisonamanda     33   Female  ...  Intermediate         0.0
# 1   TC00040  morrisonamanda     33   Female  ...  Intermediate         0.0
# 2   TC00040  morrisonamanda     33   Female  ...      Advanced         0.0
# 3   TC00040       fthornton     23   Female  ...      Beginner         0.0
# 4   TC00042       fthornton     23   Female  ...      Beginner         0.0
#
# ...

# %%
merged_df.rename(columns={
    "Age_x": "UserAge",
    "Gender_x": "UserGender",
    "Age_y": "TeacherAge",
    "Gender_y": "TeacherGender"
}, inplace=True)

# %%
merged_df.head()
# Out:
#   TransactionID  UserID CourseID TransactionDate  Amount  PaymentMethod  \
# 0       TT00001  U00003  CR00016      2025-10-25     0.0         PayPal
# 1       TT00002  U00003  CR00037      2025-01-13     0.0         PayPal
# 2       TT00003  U00003  CR00019      2025-03-28     0.0  Bank Transfer
# 3       TT00004  U00004  CR00048      2025-06-02     0.0  Bank Transfer
# 4       TT00005  U00004  CR00060      2025-08-10     0.0         PayPal
#
#   TeacherID        UserName  UserAge UserGender  ...   CourseLevel  \
# 0   TC00040  morrisonamanda       33     Female  ...  Intermediate
# 1   TC00040  morrisonamanda       33     Female  ...  Intermediate
# 2   TC00040  morrisonamanda       33     Female  ...      Advanced
# 3   TC00040       fthornton       23     Female  ...      Beginner
# 4   TC00042       fthornton       23     Female  ...      Beginner
#
#   CoursePrice CourseDuration CourseRating      TeacherName  TeacherAge  \
# ...

# %%
merged_df.to_excel("EduPro_Merged_Dataset.xlsx", index=False)

print("Merged Dataset Saved Successfully ✅")
# Out:
# Merged Dataset Saved Successfully ✅

# %%
# Total Revenue
total_revenue = merged_df["Amount"].sum()

# Total Transactions
total_transactions = merged_df["TransactionID"].nunique()

# Total Users
total_users = merged_df["UserID"].nunique()

# Total Courses
total_courses = merged_df["CourseID"].nunique()

# Total Teachers
total_teachers = merged_df["TeacherID"].nunique()

print("Total Revenue :", total_revenue)
print("Total Transactions :", total_transactions)
print("Total Users :", total_users)
print("Total Courses :", total_courses)
print("Total Teachers :", total_teachers)
# Out:
# Total Revenue : 911323.47
# Total Transactions : 10000
# Total Users : 3000
# Total Courses : 60
# Total Teachers : 60

# %%
merged_df["CourseType"].value_counts()
# Out:
# CourseType
# Free    6403
# Paid    3597
# Name: count, dtype: int64

# %%
merged_df["CourseCategory"].value_counts()
# Out:
# CourseCategory
# Data Science               916
# Finance                    864
# Web Development            844
# Business                   833
# Artificial Intelligence    829
# Project Management         829
# Design                     827
# Cybersecurity              819
# Machine Learning           819
# Digital Marketing          808
# Marketing                  806
# Programming                806
# Name: count, dtype: int64

# %%
merged_df["CourseLevel"].value_counts()
# Out:
# CourseLevel
# Beginner        3573
# Advanced        3475
# Intermediate    2952
# Name: count, dtype: int64

# %%
merged_df["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# PayPal           3389
# Credit Card      3333
# Bank Transfer    3278
# Name: count, dtype: int64

# %%
payment_revenue = merged_df.groupby("PaymentMethod")["Amount"].sum().sort_values(ascending=False)

print(payment_revenue)
# Out:
# PaymentMethod
# PayPal           305580.74
# Bank Transfer    305052.21
# Credit Card      300690.52
# Name: Amount, dtype: float64

# %%
merged_df["Month"] = merged_df["TransactionDate"].dt.to_period("M").astype(str)

monthly_revenue = merged_df.groupby("Month")["Amount"].sum()

print(monthly_revenue)
# Out:
# Month
# 2025-01    83039.70
# 2025-02    66983.84
# 2025-03    81619.62
# 2025-04    78656.48
# 2025-05    72283.85
# 2025-06    80465.73
# 2025-07    72381.81
# 2025-08    67602.50
# 2025-09    81051.05
# 2025-10    71287.01
# 2025-11    83352.94
# 2025-12    72598.94
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(12,5))
monthly_revenue.plot(kind="line", marker="o")
plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
monthly_enrollment = merged_df.groupby("Month")["TransactionID"].count()

print(monthly_enrollment)
# Out:
# Month
# 2025-01    833
# 2025-02    766
# 2025-03    857
# 2025-04    831
# 2025-05    825
# 2025-06    899
# 2025-07    826
# 2025-08    844
# 2025-09    870
# 2025-10    762
# 2025-11    869
# 2025-12    818
# Name: TransactionID, dtype: int64

# %%
plt.figure(figsize=(12,5))
monthly_enrollment.plot(kind="line", marker="o")
plt.title("Monthly Enrollment Trend")
plt.xlabel("Month")
plt.ylabel("Number of Enrollments")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
top_courses_revenue = (
    merged_df.groupby("CourseName")["Amount"]
    .sum()
    .sort_values(ascending=False)
    .head(10)
)

print(top_courses_revenue)
# Out:
# CourseName
# Computer Vision           85416.60
# Business Strategy         84410.16
# Python Basics             77453.92
# Deep Learning             67861.51
# Data Encryption           59139.00
# Project Planning          57900.57
# Statistical Analysis      57517.44
# Leadership in Projects    57070.26
# Risk Management           54132.38
# Entrepreneurship 101      49229.02
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(10,6))
top_courses_revenue.sort_values().plot(kind="barh")
plt.title("Top 10 Courses by Revenue")
plt.xlabel("Revenue")
plt.ylabel("Course")
plt.show()

# %%
top_courses_enrollment = (
    merged_df.groupby("CourseName")["TransactionID"]
    .count()
    .sort_values(ascending=False)
    .head(10)
)

print(top_courses_enrollment)
# Out:
# CourseName
# Deep Learning                    334
# Natural Language Processing      321
# Data Analysis with Python        196
# Social Media Strategy            194
# Statistical Analysis             192
# AI Ethics                        186
# Machine Learning Fundamentals    185
# Investment Strategies            183
# Corporate Finance                182
# 3D Modeling                      180
# Name: TransactionID, dtype: int64

# %%
plt.figure(figsize=(10,6))
top_courses_enrollment.sort_values().plot(kind="barh")
plt.title("Top 10 Courses by Enrollment")
plt.xlabel("Number of Enrollments")
plt.ylabel("Course")
plt.show()

# %%
course_analysis = (
    merged_df.groupby(
        ["CourseID", "CourseName", "CourseCategory",
         "CourseType", "CourseLevel", "CoursePrice",
         "CourseDuration", "CourseRating"]
    )
    .agg(
        EnrollmentCount=("TransactionID", "count"),
        CourseRevenue=("Amount", "sum"),
        TeacherExperience=("YearsOfExperience", "mean"),
        TeacherRating=("TeacherRating", "mean")
    )
    .reset_index()
)

course_analysis.head()
# Out:
#   CourseID              CourseName CourseCategory CourseType   CourseLevel  \
# 0  CR00001           Python Basics    Programming       Paid      Beginner
# 1  CR00002        Java Programming    Programming       Free  Intermediate
# 2  CR00003       C++ for Beginners    Programming       Free      Beginner
# 3  CR00004         Advanced Python    Programming       Free      Beginner
# 4  CR00005  Full Stack Development    Programming       Free      Beginner
#
#    CoursePrice  CourseDuration  CourseRating  EnrollmentCount  CourseRevenue  \
# 0       472.28           11.00          4.74              164       77453.92
# 1         0.00           37.70          2.43              149           0.00
# 2         0.00           19.53          3.85              173           0.00
# 3         0.00           45.13          2.88              154           0.00
# 4         0.00           28.68          1.28              166           0.00
#
#    TeacherExperience  TeacherRating
# ...

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    course_analysis["CoursePrice"],
    course_analysis["CourseRevenue"]
)

plt.title("Course Price vs Revenue")
plt.xlabel("Course Price")
plt.ylabel("Course Revenue")
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    course_analysis["CourseRating"],
    course_analysis["CourseRevenue"]
)

plt.title("Course Rating vs Revenue")
plt.xlabel("Course Rating")
plt.ylabel("Course Revenue")
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    course_analysis["CourseDuration"],
    course_analysis["EnrollmentCount"]
)

plt.title("Course Duration vs Enrollment")
plt.xlabel("Course Duration")
plt.ylabel("Enrollment Count")
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    course_analysis["TeacherExperience"],
    course_analysis["CourseRevenue"]
)

plt.title("Teacher Experience vs Course Revenue")
plt.xlabel("Teacher Experience")
plt.ylabel("Course Revenue")
plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    course_analysis["TeacherRating"],
    course_analysis["CourseRevenue"]
)

plt.title("Teacher Rating vs Course Revenue")
plt.xlabel("Teacher Rating")
plt.ylabel("Course Revenue")
plt.show()

# %%
course_analysis.to_excel("EduPro_Course_Level_Dataset.xlsx", index=False)

print("Course Level Dataset Saved Successfully ✅")
# Out:
# Course Level Dataset Saved Successfully ✅

# %%
print("Rows:", course_analysis.shape[0])
print("Columns:", course_analysis.shape[1])

course_analysis.info()
# Out:
# Rows: 60
# Columns: 12
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CourseID           60 non-null     object
#  1   CourseName         60 non-null     object
#  2   CourseCategory     60 non-null     object
#  3   CourseType         60 non-null     object
#  4   CourseLevel        60 non-null     object
#  5   CoursePrice        60 non-null     float64
#  6   CourseDuration     60 non-null     float64
#  7   CourseRating       60 non-null     float64
#  8   EnrollmentCount    60 non-null     int64
#  9   CourseRevenue      60 non-null     float64
#  10  TeacherExperience  60 non-null     float64
#  11  TeacherRating      60 non-null     float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 5.8+ KB

# %%
# Machine Learning

# %%
import pandas as pd

ml_df = pd.read_excel("EduPro_Course_Level_Dataset.xlsx")

print("Dataset Shape:", ml_df.shape)
ml_df.head()
# Out:
# Dataset Shape: (60, 12)
#   CourseID              CourseName CourseCategory CourseType   CourseLevel  \
# 0  CR00001           Python Basics    Programming       Paid      Beginner
# 1  CR00002        Java Programming    Programming       Free  Intermediate
# 2  CR00003       C++ for Beginners    Programming       Free      Beginner
# 3  CR00004         Advanced Python    Programming       Free      Beginner
# 4  CR00005  Full Stack Development    Programming       Free      Beginner
#
#    CoursePrice  CourseDuration  CourseRating  EnrollmentCount  CourseRevenue  \
# 0       472.28           11.00          4.74              164       77453.92
# 1         0.00           37.70          2.43              149           0.00
# 2         0.00           19.53          3.85              173           0.00
# 3         0.00           45.13          2.88              154           0.00
# 4         0.00           28.68          1.28              166           0.00
#
# ...

# %%
# Target variable
y = ml_df["EnrollmentCount"]

# Features
X = ml_df[
    [
        "CourseCategory",
        "CourseType",
        "CourseLevel",
        "CoursePrice",
        "CourseDuration",
        "CourseRating",
        "TeacherExperience",
        "TeacherRating"
    ]
]

print("Features (X):")
print(X.head())

print("\nTarget (y):")
print(y.head())

print("\nX Shape:", X.shape)
print("y Shape:", y.shape)
# Out:
# Features (X):
#   CourseCategory CourseType   CourseLevel  CoursePrice  CourseDuration  \
# 0    Programming       Paid      Beginner       472.28           11.00
# 1    Programming       Free  Intermediate         0.00           37.70
# 2    Programming       Free      Beginner         0.00           19.53
# 3    Programming       Free      Beginner         0.00           45.13
# 4    Programming       Free      Beginner         0.00           28.68
#
#    CourseRating  TeacherExperience  TeacherRating
# 0          4.74          16.682927       4.191646
# 1          2.43          17.013423       4.211409
# 2          3.85          16.589595       4.079017
# 3          2.88          15.896104       4.097987
# 4          1.28          15.795181       4.058554
#
# Target (y):
# 0    164
# 1    149
# 2    173
# 3    154
# 4    166
# Name: EnrollmentCount, dtype: int64
#
# X Shape: (60, 8)
# y Shape: (60,)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

categorical_features = [
    "CourseCategory",
    "CourseType",
    "CourseLevel"
]

preprocessor = ColumnTransformer(
    transformers=[
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_features)
    ],
    remainder="passthrough"
)

X_encoded = preprocessor.fit_transform(X)

print("Original X Shape:", X.shape)
print("Encoded X Shape:", X_encoded.shape)
# Out:
# Original X Shape: (60, 8)
# Encoded X Shape: (60, 22)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded,
    y,
    test_size=0.20,
    random_state=42
)

print("Training Data:", X_train.shape)
print("Testing Data:", X_test.shape)
# Out:
# Training Data: (48, 22)
# Testing Data: (12, 22)

# %%
from sklearn.linear_model import LinearRegression

linear_model = LinearRegression()

linear_model.fit(X_train, y_train)

linear_pred = linear_model.predict(X_test)

print("Linear Regression Model Trained Successfully ✅")
# Out:
# Linear Regression Model Trained Successfully ✅

# %%
from sklearn.ensemble import RandomForestRegressor

rf_model = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)

print("Random Forest Model Trained Successfully ✅")
# Out:
# Random Forest Model Trained Successfully ✅

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb_model = GradientBoostingRegressor(
    n_estimators=100,
    random_state=42
)

gb_model.fit(X_train, y_train)

gb_pred = gb_model.predict(X_test)

print("Gradient Boosting Model Trained Successfully ✅")
# Out:
# Gradient Boosting Model Trained Successfully ✅

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def evaluate_model(name, actual, predicted):
    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    r2 = r2_score(actual, predicted)

    print(name)
    print("MAE :", round(mae, 2))
    print("RMSE:", round(rmse, 2))
    print("R²  :", round(r2, 4))
    print("-" * 40)

evaluate_model("Linear Regression", y_test, linear_pred)
evaluate_model("Random Forest", y_test, rf_pred)
evaluate_model("Gradient Boosting", y_test, gb_pred)
# Out:
# Linear Regression
# MAE : 12.39
# RMSE: 16.49
# R²  : -0.4914
# ----------------------------------------
# Random Forest
# MAE : 10.88
# RMSE: 13.46
# R²  : 0.0053
# ----------------------------------------
# Gradient Boosting
# MAE : 12.2
# RMSE: 15.49
# R²  : -0.3166
# ----------------------------------------

# %%
model_results = []

models = [
    ("Linear Regression", linear_pred),
    ("Random Forest", rf_pred),
    ("Gradient Boosting", gb_pred)
]

for name, predictions in models:

    mae = mean_absolute_error(y_test, predictions)
    rmse = np.sqrt(mean_squared_error(y_test, predictions))
    r2 = r2_score(y_test, predictions)

    model_results.append({
        "Model": name,
        "MAE": mae,
        "RMSE": rmse,
        "R2 Score": r2
    })

results_df = pd.DataFrame(model_results)

results_df = results_df.sort_values(
    by="R2 Score",
    ascending=False
)

results_df
# Out:
#                Model        MAE       RMSE  R2 Score
# 1      Random Forest  10.877917  13.462907  0.005336
# 2  Gradient Boosting  12.197612  15.489073 -0.316587
# 0  Linear Regression  12.389243  16.485186 -0.491373

# %%
best_model_name = results_df.iloc[0]["Model"]

print("Best Model:", best_model_name)
# Out:
# Best Model: Random Forest

# %%
if best_model_name == "Linear Regression":
    best_predictions = linear_pred

elif best_model_name == "Random Forest":
    best_predictions = rf_pred

else:
    best_predictions = gb_pred

comparison_df = pd.DataFrame({
    "Actual Enrollment": y_test.values,
    "Predicted Enrollment": best_predictions
})

comparison_df.head(10)
# Out:
#    Actual Enrollment  Predicted Enrollment
# 0                164               168.165
# 1                156               167.385
# 2                153               170.415
# 3                140               167.730
# 4                171               169.795
# 5                178               167.130
# 6                150               162.230
# 7                163               169.225
# 8                170               162.580
# 9                194               170.855

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    comparison_df["Actual Enrollment"],
    comparison_df["Predicted Enrollment"]
)

plt.xlabel("Actual Enrollment")
plt.ylabel("Predicted Enrollment")
plt.title("Actual vs Predicted Enrollment")

plt.show()

# %%
comparison_df["Prediction Error"] = (
    comparison_df["Actual Enrollment"]
    - comparison_df["Predicted Enrollment"]
)

comparison_df.head(10)
# Out:
#    Actual Enrollment  Predicted Enrollment  Prediction Error
# 0                164               168.165            -4.165
# 1                156               167.385           -11.385
# 2                153               170.415           -17.415
# 3                140               167.730           -27.730
# 4                171               169.795             1.205
# 5                178               167.130            10.870
# 6                150               162.230           -12.230
# 7                163               169.225            -6.225
# 8                170               162.580             7.420
# 9                194               170.855            23.145

# %%
feature_names = preprocessor.get_feature_names_out()

feature_importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": rf_model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance.head(15)
# Out:
#                                         Feature  Importance
# 19                      remainder__CourseRating    0.238443
# 18                    remainder__CourseDuration    0.183696
# 3              cat__CourseCategory_Data Science    0.141315
# 20                 remainder__TeacherExperience    0.095593
# 21                     remainder__TeacherRating    0.084441
# 5         cat__CourseCategory_Digital Marketing    0.045432
# 16                cat__CourseLevel_Intermediate    0.037172
# 15                    cat__CourseLevel_Beginner    0.029569
# 8                 cat__CourseCategory_Marketing    0.027995
# 6                   cat__CourseCategory_Finance    0.022118
# 17                       remainder__CoursePrice    0.017736
# 0   cat__CourseCategory_Artificial Intelligence    0.016318
# 14                    cat__CourseLevel_Advanced    0.013498
# 9               cat__CourseCategory_Programming    0.010266
# 4                    cat__CourseCategory_Design    0.009210

# %%
plt.figure(figsize=(10,6))

feature_importance.head(10).sort_values(
    "Importance"
).plot(
    x="Feature",
    y="Importance",
    kind="barh",
    legend=False
)

plt.title("Top 10 Features Influencing Enrollment")
plt.xlabel("Importance")
plt.ylabel("Feature")

plt.show()

# %%
results_df.to_excel(
    "EduPro_Enrollment_Model_Results.xlsx",
    index=False
)

print("Model Results Saved Successfully ✅")
# Out:
# Model Results Saved Successfully ✅

# %%
# Revenue ko target variable banate hain

y_revenue = ml_df["CourseRevenue"]

print("Revenue Target:")
print(y_revenue.head())

print("\nTarget Shape:", y_revenue.shape)
# Out:
# Revenue Target:
# 0    77453.92
# 1        0.00
# 2        0.00
# 3        0.00
# 4        0.00
# Name: CourseRevenue, dtype: float64
#
# Target Shape: (60,)

# %%
from sklearn.model_selection import train_test_split

X_train_rev, X_test_rev, y_train_rev, y_test_rev = train_test_split(
    X_encoded,
    y_revenue,
    test_size=0.20,
    random_state=42
)

print("Training Data:", X_train_rev.shape)
print("Testing Data:", X_test_rev.shape)
# Out:
# Training Data: (48, 22)
# Testing Data: (12, 22)

# %%
from sklearn.linear_model import LinearRegression

linear_rev_model = LinearRegression()

linear_rev_model.fit(X_train_rev, y_train_rev)

linear_rev_pred = linear_rev_model.predict(X_test_rev)

print("Revenue Linear Regression Trained Successfully ✅")
# Out:
# Revenue Linear Regression Trained Successfully ✅

# %%
from sklearn.ensemble import RandomForestRegressor

rf_rev_model = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

rf_rev_model.fit(X_train_rev, y_train_rev)

rf_rev_pred = rf_rev_model.predict(X_test_rev)

print("Revenue Random Forest Trained Successfully ✅")
# Out:
# Revenue Random Forest Trained Successfully ✅

# %%
from sklearn.ensemble import GradientBoostingRegressor

gb_rev_model = GradientBoostingRegressor(
    n_estimators=100,
    random_state=42
)

gb_rev_model.fit(X_train_rev, y_train_rev)

gb_rev_pred = gb_rev_model.predict(X_test_rev)

print("Revenue Gradient Boosting Trained Successfully ✅")
# Out:
# Revenue Gradient Boosting Trained Successfully ✅

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def evaluate_revenue_model(name, actual, predicted):

    mae = mean_absolute_error(actual, predicted)
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    r2 = r2_score(actual, predicted)

    print(name)
    print("MAE :", round(mae, 2))
    print("RMSE:", round(rmse, 2))
    print("R²  :", round(r2, 4))
    print("-" * 40)


evaluate_revenue_model(
    "Linear Regression",
    y_test_rev,
    linear_rev_pred
)

evaluate_revenue_model(
    "Random Forest",
    y_test_rev,
    rf_rev_pred
)

evaluate_revenue_model(
    "Gradient Boosting",
    y_test_rev,
    gb_rev_pred
)
# Out:
# Linear Regression
# MAE : 3644.82
# RMSE: 4191.06
# R²  : 0.9774
# ----------------------------------------
# Random Forest
# MAE : 4763.52
# RMSE: 7020.4
# R²  : 0.9365
# ----------------------------------------
# Gradient Boosting
# MAE : 5563.38
# RMSE: 7924.12
# R²  : 0.9191
# ----------------------------------------

# %%
revenue_model_results = []

revenue_models = [
    ("Linear Regression", linear_rev_pred),
    ("Random Forest", rf_rev_pred),
    ("Gradient Boosting", gb_rev_pred)
]

for name, predictions in revenue_models:

    mae = mean_absolute_error(y_test_rev, predictions)
    rmse = np.sqrt(mean_squared_error(y_test_rev, predictions))
    r2 = r2_score(y_test_rev, predictions)

    revenue_model_results.append({
        "Model": name,
        "MAE": mae,
        "RMSE": rmse,
        "R2 Score": r2
    })

revenue_results_df = pd.DataFrame(revenue_model_results)

revenue_results_df = revenue_results_df.sort_values(
    by="R2 Score",
    ascending=False
)

revenue_results_df
# Out:
#                Model          MAE         RMSE  R2 Score
# 0  Linear Regression  3644.823146  4191.060678  0.977370
# 1      Random Forest  4763.519713  7020.401830  0.936503
# 2  Gradient Boosting  5563.378593  7924.124017  0.919103

# %%
best_revenue_model_name = revenue_results_df.iloc[0]["Model"]

print("Best Revenue Model:", best_revenue_model_name)
# Out:
# Best Revenue Model: Linear Regression

# %%
if best_revenue_model_name == "Linear Regression":

    best_revenue_predictions = linear_rev_pred

elif best_revenue_model_name == "Random Forest":

    best_revenue_predictions = rf_rev_pred

else:

    best_revenue_predictions = gb_rev_pred


revenue_comparison_df = pd.DataFrame({
    "Actual Revenue": y_test_rev.values,
    "Predicted Revenue": best_revenue_predictions
})

revenue_comparison_df.head(10)
# Out:
#    Actual Revenue  Predicted Revenue
# 0        77453.92       81929.113292
# 1        43113.72       46226.425158
# 2            0.00       -1471.940664
# 3        34734.00       42022.684102
# 4            0.00       -1959.064568
# 5        10202.96        6721.613366
# 6        59139.00       67739.449822
# 7        67728.13       70219.825467
# 8            0.00       -2808.110715
# 9            0.00       -2358.482534

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.scatter(
    revenue_comparison_df["Actual Revenue"],
    revenue_comparison_df["Predicted Revenue"]
)

plt.xlabel("Actual Revenue")
plt.ylabel("Predicted Revenue")
plt.title("Actual vs Predicted Course Revenue")

plt.show()

# %%
revenue_comparison_df["Prediction Error"] = (
    revenue_comparison_df["Actual Revenue"]
    - revenue_comparison_df["Predicted Revenue"]
)

revenue_comparison_df.head(10)
# Out:
#    Actual Revenue  Predicted Revenue  Prediction Error
# 0        77453.92       81929.113292      -4475.193292
# 1        43113.72       46226.425158      -3112.705158
# 2            0.00       -1471.940664       1471.940664
# 3        34734.00       42022.684102      -7288.684102
# 4            0.00       -1959.064568       1959.064568
# 5        10202.96        6721.613366       3481.346634
# 6        59139.00       67739.449822      -8600.449822
# 7        67728.13       70219.825467      -2491.695467
# 8            0.00       -2808.110715       2808.110715
# 9            0.00       -2358.482534       2358.482534

# %%
feature_names = preprocessor.get_feature_names_out()

revenue_feature_importance = pd.DataFrame({
    "Feature": feature_names,
    "Importance": rf_rev_model.feature_importances_
})

revenue_feature_importance = revenue_feature_importance.sort_values(
    by="Importance",
    ascending=False
)

revenue_feature_importance.head(15)
# Out:
#                                         Feature  Importance
# 17                       remainder__CoursePrice    0.938788
# 21                     remainder__TeacherRating    0.023841
# 20                 remainder__TeacherExperience    0.013600
# 13                         cat__CourseType_Paid    0.007751
# 18                    remainder__CourseDuration    0.004989
# 12                         cat__CourseType_Free    0.002667
# 19                      remainder__CourseRating    0.002281
# 5         cat__CourseCategory_Digital Marketing    0.002072
# 1                  cat__CourseCategory_Business    0.001874
# 14                    cat__CourseLevel_Advanced    0.000691
# 0   cat__CourseCategory_Artificial Intelligence    0.000545
# 10       cat__CourseCategory_Project Management    0.000395
# 15                    cat__CourseLevel_Beginner    0.000201
# 6                   cat__CourseCategory_Finance    0.000145
# 16                cat__CourseLevel_Intermediate    0.000125

# %%
plt.figure(figsize=(10,6))

revenue_feature_importance.head(10).sort_values(
    "Importance"
).plot(
    x="Feature",
    y="Importance",
    kind="barh",
    legend=False
)

plt.title("Top 10 Features Influencing Course Revenue")
plt.xlabel("Importance")
plt.ylabel("Feature")

plt.show()

# %%
revenue_results_df.to_excel(
    "EduPro_Revenue_Model_Results.xlsx",
    index=False
)

print("Revenue Model Results Saved Successfully ✅")
# Out:
# Revenue Model Results Saved Successfully ✅

# %%
revenue_comparison_df.to_excel(
    "EduPro_Revenue_Predictions.xlsx",
    index=False
)

print("Revenue Predictions Saved Successfully ✅")
# Out:
# Revenue Predictions Saved Successfully ✅

# %%
revenue_feature_importance.to_excel(
    "EduPro_Revenue_Feature_Importance.xlsx",
    index=False
)

print("Revenue Feature Importance Saved Successfully ✅")
# Out:
# Revenue Feature Importance Saved Successfully ✅
